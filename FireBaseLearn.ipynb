# %%
import firebase_admin
from firebase_admin import credentials,firestore

cred = credentials.Certificate("serviceAccountKey.json")
firebase_admin.initialize_app(cred)

# %%
db = firestore.client()
response = db.collection('Phone')
docs = response.get()


for doc in docs:
    print('{} => {}'.format(doc.id, doc.to_dict()))
# Out:
# A5 => {'id': '18', 'Name': 'A5', 'Specification': {'CPU': 'Octa-core, 1.8 GHz', 'Network': 'GSM/LTE/HSPA', 'Chipset': 'Qualcomm Snapdragon 450', 'GPU': 'Adreno 506', 'Resolution': 'HD+ 720 x 1520 pixels (271 ppi)', 'os': 'Android Oreo v8.1 (Color OS 5.1)', 'Display': 'Full-View In-Cell Touchscreen', 'Memory': '32 GB ROM, 4 GB RAM', 'Selfie Camera': '8 MP- F/2.2 aperture', 'Main Camera': '13+2 Megapixel- F/2.2 & f/2.4, autofocus, depth sensor, LED flash, face detection, HDR, panorama', 'Size': '6.2 inches', 'Battery': 'Lithium-ion 4230 mAh (non-removable)'}, 'imageUrl': 'https://firebasestorage.googleapis.com/v0/b/e-commerecreact.appspot.com/o/image%2FOppo-A5.jpg?alt=media&token=89aa841c-dd90-4d24-ae8b-2eef2df22fc5', 'Brand': 'Oppo', 'price': '19,990'}
# A7 => {'id': '17', 'Specification': {'CPU': 'Octa-core, 1.8 GHz', 'Network': 'GSM/LTE/HSPA', 'GPU': 'Adreno 506', 'Chipset': 'Qualcomm Snapdragon 450 (14 nm)', 'Resolution': 'Full HD+ 1080 x 2160 pixels (403 ppi)', 'Display': '19:9 ratio Full-View IPS LCD In-Cell Touchscreen with Corning Gorilla Glass 3 protection', 'os': 'Android Oreo v8.1 (Color OS 5.2)', 'Selfie Camera': '16 MP- F/2.0 aperture, HDR', 'Memory': '64 GB ROM, 4 GB RAM', 'Main Camera': 'Dual 13+2 Megapixel- F/2.2 & f/2.4 aperture, autofocus, depth sensor, LED flash, HDR, panorama', 'Battery': 'Lithium-ion 4230 mAh (non-removable)', 'Size': '6.2 inches'}, 'Name': 'A7', 'imageUrl': 'https://firebasestorage.googleapis.com/v0/b/e-commerecreact.appspot.com/o/image%2Foppo%20A7.jpg?alt=media&token=c43ccf3f-53cf-4b3a-b7af-b3d3cb4c804d', 'Brand': 'Oppo', 'price': '24,990'}
# F7 => {'id': '20', 'Specification': {'CPU': 'Octa-core, 2.0 GHz', 'Network': 'GSM/LTE/HSPA', 'Chipset': 'Helio P60', 'GPU': 'Mali-G72 MP3', 'Resolution': 'HD 720 x 1280 pixels (295 ppi)', 'Display': 'LTPS IPS TFT Full-View (88%) screen with Corning Gorilla Glass 5 protection', 'os': 'Android Oreo v8.1 (based on MIUI 9.0)', 'Memory': '16 GB ROM, 2 GB RAM', 'Selfie Camera': '  5 Megapixel- F/2.2 aperture, portrait mode, HDR)', 'Main Camera': '13 Megapixel- Phase detection autofocus (PDAF), HDR, panorama, low light photo enhancement', 'Size': '5.45 inches', 'Battery': 'Lithium-ion 3400 mAh (non-removable)'}, 'Name': 'F7', 'imageUrl': 'https://firebasestorage.googleapis.com/v0/b/e-commerecreact.appspot.com/o/image%2FF7.jpg?alt=media&token=a11807b8-7a3c-4133-9720-91891bfaf3f4', 'price': '27,990', 'Brand': 'Oppo'}
# F9 => {'id': '19', 'Name': 'F9', 'Specification': {'CPU': 'Octa-core (4x2.45 GHz & 4x1.9 GHz)', 'Network': 'GSM/LTE/HSPA', 'GPU': 'Adreno 540', 'Chipset': 'Qualcomm Snapdragon 835', 'Resolution': 'Full HD+ 1080 x 2160 pixels (403 ppi)', 'Display': 'Full-View 18:9 IPS LCD Touchscreen, Corning Gorilla Glass 4 protection', 'os': 'Android Nougat v7.1 (based on MIUI 9.0)', 'Selfie Camera': '  5 Megapixel- F/2.0, full HD video rec.', 'Memory': '64 GB ROM, 6 GB RAM', 'Main Camera': '12 Megapixel- F/2.0, 1/2.9, 1.25 µm, PDAF, 4-axis OIS, dual-LED flash, face detection, HDR, panorama, Sony IMX386 sensor', 'Battery': 'Lithium-polymer 3500 mAh (non-removable)- Fast battery charging: VOOC Flash Charge', 'Size': '5.99 inches'}, 'imageUrl': 'https://firebasestorage.googleapis.com/v0/b/e-commerecreact.appspot.com/o/image%2FF9.jpg?alt=media&token=e4325986-c888-42a2-9f99-405d5f2eda7b', 'Brand': 'Oppo', 'price': '28,990'}
# Galaxy A7(2018) => {'id': '15', 'Name': 'Galaxy A7(2018)', 'Specification': {'CPU': 'Octa-core, 2.2 GHz', 'Network': 'GSM/LTE/HSPA', 'GPU': 'Mali-G71', 'Chipset': 'Exynos 7885 Octa', 'Resolution': 'Full HD+ 1080 x 2220 pixels (294 ppi)', 'Display': 'Full-View Super AMOLED Infinity display with Corning Gorilla Glass protection- Always-on Display', 'os': 'Android 8.1 (Oreo), upgradable to Android 9.0 (Pie)', 'Selfie Camera': '24 Megapixel- F/2.0, adjustable LED flash, HDR, Full HD video rec.', 'Memory': '64 GB ROM, 4 GB RAM', 'Main Camera': 'Triple 24+8+5 Megapixel- PDAF, low-light, 13mm ultrawide lens, depth sensor, live focus, LED flash, panorama, HDR', 'Battery': 'Lithium-ion 3300 mAh (non-removable)', 'Size': '6.0 inches'}, 'imageUrl': 'https://firebasestorage.googleapis.com/v0/b/e-commerecreact.appspot.com/o/image%2Famsung-galaxy-a7-2018.jpg?alt=media&token=aac9fbcc-0b42-4375-9859-bedb6b0b9886', 'Brand': 'Samsung', 'price': '28,990'}
# Galaxy A9 => {'id': '11', 'Name': 'Galaxy A9', 'Specification': {'CPU': 'Octa-core (4x2.2 GHz & 4x1.8 GHz)', 'Network': 'GSM/LTE/HSPA', 'GPU': 'Adreno 512', 'Chipset': 'Qualcomm Snapdragon 660', 'Selfei Camera': '24 Megapixel- F/2.0, HDR, Full HD video rec.', 'Resolution': '18.5:9 ratio Full-View Super AMOLED Infinity display', 'Display': 'Full HD+ 1080 x 2220 pixels (392 ppi)', 'os': 'Android 8.1 (Oreo)', 'Memory': '64/128 GB, 4/6 GB RAM or 8 GB RAM (GT version)', 'Main Camera': 'Quad 24+8+10+5 Megapixel', 'Battery': 'Lithium-ion 3750 mAh (non-removable)', 'Size': '6.3 inches'}, 'imageUrl': 'https://firebasestorage.googleapis.com/v0/b/e-commerecreact.appspot.com/o/image%2FgalaxyA9.jpg?alt=media&token=d8550885-f6f0-41d5-9e4a-4132aab18d4d', 'Brand': 'Samsung', 'price': '49,990'}
# Galaxy J7 pro => {'id': '14', 'Specification': {'CPU': 'Octa-core, 1.6 GHz', 'Network': 'GSM/LTE/HSPA', 'GPU': 'Mali-T830 MP2', 'Chipset': 'Exynos 7870 Octa', 'Resolution': 'Full HD 1080 x 1920 pixels (401 ppi)', 'Display': 'Super AMOLED Touchscreen', 'os': 'Android Nougat v7.1', 'Selfie Camera': '13 Megapixel- F/1.9, LED flash, full HD video rec.', 'Memory': '32/64 GB ROM, 3 GB RAM', 'Main Camera': '13 Megapixel- F/1.7, autofocus, LED flash, face detection, HDR, panorama', 'Battery': 'Lithium-ion 3600 mAh (non-removable)', 'Size': '5.5 inches'}, 'Name': 'Galaxy J7 pro', 'imageUrl': 'https://firebasestorage.googleapis.com/v0/b/e-commerecreact.appspot.com/o/image%2FSamsung-Galaxy-J7-Pro.jpg?alt=media&token=ce45e286-cd28-43ae-80d8-58c6fe455d0d', 'price': '24,490', 'Brand': 'Samsung'}
# Galaxy note 9 => {'id': '13', 'Name': 'Galaxy note 9', 'Specification': {'CPU': 'Octa-core (4x2.4 GHz & 4x1.8 GHz)', 'Network': 'GSM/LTE/HSPA', 'GPU': 'Mali-G72 MP18', 'Chipset': 'Exynos 9810 Octa', 'Resolution': 'qHD 1440 x 2960 pixels (516 ppi)', 'Display': '18.5:9 ratio Full-View Super AMOLED Touchscreen with Corning Gorilla Glass 5 protection', 'os': 'Android v8.1 (oreo)', 'Memory': '128 GB, 6 GB RAM', 'Selfie Camera': '  8 Megapixel- F/1.7, autofocus, 25mm, 1/3.6, 1.22µm, 1440p@30fps, dual video call, Auto HDR', 'Main Camera': 'Dual 12+12 Megapixel- 26mm, 1/2.55, 1.4 & 1µm, dual pixel PDAF, OIS, 52mm, 1/3.6, 2x optical zoom, LED flash, auto-HDR, panorama', 'Battery': 'Lithium-ion 4000 mAh (non-removable)', 'Size': '6.4 inches'}, 'imageUrl': 'https://firebasestorage.googleapis.com/v0/b/e-commerecreact.appspot.com/o/image%2FgalaxyNote9.jpg?alt=media&token=401a8830-bf88-4c2f-93a9-81ddce8946ff', 'Brand': 'Samsung', 'price': '94,900'}
# Glaxy J6+ => {'id': '12', 'Specification': {'CPU': 'Quad-core, 1.4 GHz', 'Network': 'GSM/LTE/HSPA', 'Chipset': 'Qualcomm Snapdragon 425', 'GPU': 'Adreno 308', 'Resolution': 'HD+ 720 x 1480 pixels', 'Display': '18.5:9 ration Full-View TFT Infinity Touchscreen', 'os': 'Android 8.1 (Oreo)', 'Memory': '32/64 GB, 3 GB RAM or 128 GB', 'Selfie Camera': '  8 Megapixel- F/1.9 aperture, LED flash', 'Main Camera': 'Dual 13+5 Megapixel- f/1.9 & f/2.2, depth sensor, 28mm (wide-angle lens), autofocus, LED flash, HDR, panorama, live focus, background blur shape', 'Size': '6.0 inches', 'Battery': 'Lithium-ion 3300 mAh (non-removable)'}, 'Name': 'Glaxy J6+', 'imageUrl': 'https://firebasestorage.googleapis.com/v0/b/e-commerecreact.appspot.com/o/image%2FgalaxyJ6%2B.webp?alt=media&token=6b8e75d9-73a9-45cb-9ed6-ab244c611c2a', 'price': '18,990', 'Brand': 'Samsung'}
# Honor 10 => {'id': '1', 'Specification': {'CPU': 'Octa-core (4x2.4 GHz Cortex-A73 & 4x1.8 GHz Cortex-A53)', 'Network': 'GSM/LTE/HSPA', 'GPU': 'Mali-G72 MP12', 'Chipset': 'Hisilicon Kirin 970 (10 nm)', 'Selfei Camera': '24 MP, f/2.0,24 MP, f/2.0', 'Resolution': '1080 x 2280 pixels, 19:9 ratio (~432 ppi density)', 'Display': 'IPS LCD capacitive touchscreen, 16M colors', 'os': 'Android 8.1 (Oreo)', 'Memory': '64/128 GB, 4/6 GB RAM or 8 GB RAM (GT version)', 'Main Camera': '16 MP, f/1.8, PDAF 24 MP B/W, f/1.8, PDAF,2160p@30fps, 1080p@30/60fps (gyro-EIS)', 'Battery': 'Non-removable Li-Po 3400 mAh battery', 'Size': '5.84 inches'}, 'Name': 'Honor 10', 'imageUrl': 'https://firebasestorage.googleapis.com/v0/b/e-commerecreact.appspot.com/o/image%2FHonor10.jpg?alt=media&token=ea70cb96-0e86-4189-8d6f-a9e18c1c301b', 'price': '25,000', 'Brand': 'Huawei'}
# MI A2 => {'id': '7', 'Specification': {'CPU': 'Octa-core (4x2.2 and 4x1.8 GHz)', 'Network': 'GSM/LTE/HSPA', 'Chipset': 'HiSilicon Kirin 659 (16 nm)', 'GPU': 'Adreno 512', 'Resolution': 'Full HD+ 1080 x 2160 pixels (403 ppi)', 'Display': '18:9 ratio Full-View LTPS IPS LCD Touchscreen with Corning Gorilla Glass 5 protection', 'os': 'Android Oreo v8.1 (Android One) based on MIUI 9.0', 'Memory': '64 GB ROM, 4 GB RAM', 'Selfie Camera': '20 Megapixel- f/2.2, 1/2.8, 1.0µm, LED flash, Auto-HDR, full-HD video rec.', 'Main Camera': 'Dual 12+20 Megapixel- 2x f/1.8, 1/2.9 & 1/2.8, 1.25 & 1.0µm, PDAF, dual-LED flash, HDR, panorama, bokeh, Sony IMX 376 sensor', 'Size': '5.99 inches', 'Battery': 'Lithium-ion 3000 mAh (non-removable)- Fast battery charging 5V/2A/10W (Quick Charge 3.0)'}, 'Name': 'MI A2', 'imageUrl': 'https://firebasestorage.googleapis.com/v0/b/e-commerecreact.appspot.com/o/image%2Fmia2.jpg?alt=media&token=f3594587-1ec1-4b5b-95c2-875f70864997', 'price': '23,999', 'Brand': 'Xiaomi'}
# MI MIX 2 => {'id': '9', 'Name': 'MI MIX 2', 'Specification': {'CPU': 'Octa-core (4x2.45 GHz & 4x1.9 GHz)', 'Network': 'GSM/LTE/HSPA', 'GPU': 'Adreno 540', 'Chipset': 'Qualcomm Snapdragon 835', 'Resolution': 'Full HD+ 1080 x 2160 pixels (403 ppi)', 'Display': 'Full-View 18:9 IPS LCD Touchscreen, Corning Gorilla Glass 4 protection', 'os': 'Android Nougat v7.1 (based on MIUI 9.0)', 'Memory': '64 GB ROM, 6 GB RAM', 'Selfie Camera': '  5 Megapixel- F/2.0, full HD video rec.', 'Main Camera': '12 Megapixel- F/2.0, 1/2.9, 1.25 µm, PDAF, 4-axis OIS, dual-LED flash, face detection, HDR, panorama, Sony IMX386 sensor', 'Battery': 'Lithium-ion 3400 mAh (non-removable)', 'Size': '5.99 inches'}, 'imageUrl': 'https://firebasestorage.googleapis.com/v0/b/e-commerecreact.appspot.com/o/image%2Fmi%20mix2.jpg?alt=media&token=e255c37c-5df5-4a72-bdad-1eac812615b6', 'Brand': 'Xiaomi', 'price': '56,490'}
# Nove-3e => {'id': '2', 'Name': 'Nove-3e', 'Specification': {'CPU': 'Octa-core (4x2.36 GHz Cortex-A53 & 4x1.7 GHz Cortex-A53)', 'Network': 'GSM/LTE/HSPA', 'Chipset': 'HiSilicon Kirin 659 (16 nm)', 'GPU': 'Mali-T830 MP2', 'Resolution': '1080 x 2280 pixels, 19:9 ratio (~432 ppi density)', 'Display': 'LTPS IPS LCD capacitive touchscreen, 16M colors', 'os': 'Android 8.0 (Oreo)', 'Memory': '32/64 GB, 4 GB RAM or 128 GB', 'Selfie Camera': '16 MP, f/2.0, 28mm (wide), 1.12µm 24 MP, f/2.0 ,1080p@30fps', 'Main Camera': '16 MP, f/2.2, 1.0µm, PDAF 2 MP, depth sensor,1080p@30fps', 'Size': '5.84 inches', 'Battery': 'Non - removable Li - Po 3000 mAh battery '}, 'imageUrl': 'https://firebasestorage.googleapis.com/v0/b/e-commerecreact.appspot.com/o/image%2FNova-3e.jpg?alt=media&token=cdc1f1b5-76c3-4124-b1ea-9c92bda4dc45', 'Brand': 'Huawei', 'price': '27,900'}
# Pocofone F1 => {'id': '6', 'Name': 'Pocofone F1', 'Specification': {'CPU': 'Octa-core (4x2.8 and 4x1.8 GHz)', 'Network': 'GSM/LTE/HSPA', 'GPU': 'Adreno 630', 'Chipset': 'Qualcomm Snapdragon 845', 'Selfei Camera': '20 Megapixel- f/2.0, superpixel, 0.9µm, HDR, full-HD video rec.', 'Resolution': '18.7:9 ratio Full-View IPS LCD Touchscreen with Corning Gorilla Glass protection (unspecified version)', 'os': 'Android Oreo v8.1 based on MIUI 9.6 (POCO customization)', 'Display': 'Full HD+ 1080 x 2246 pixels (403 ppi)', 'Memory': '64/128 GB ROM, 4/6 GB RAM', 'Main Camera': 'Dual 12+5 Megapixel- f/1.9 & f/2.0, 1/2.55, 1.4 & 1.12µm, dual pixel PDAF, depth sensor, Dual-LED flash, HDR, panorama, portrait bokeh, face detection, EIS', 'Battery': 'Lithium-polymer 4000 mAh (non-removable)- Fast Battery Charging (Quick Charge 3.0)', 'Size': '6.18 inches'}, 'imageUrl': 'https://firebasestorage.googleapis.com/v0/b/e-commerecreact.appspot.com/o/image%2Fpocof1.jpg?alt=media&token=141892a0-4363-440b-9194-f93e1bbdf492', 'Brand': 'Xiaomi', 'price': '29,999'}
# R17 Pro => {'id': '16', 'Specification': {'CPU': 'Octa-core (2x2.2 & 6x1.7 GHz)', 'Network': 'GSM/LTE/HSPA', 'Chipset': 'Qualcomm Snapdragon 710', 'GPU': 'Adreno 616', 'Selfei Camera': '20 Megap25 Megapixel- F/2.0, 1/2.8, 0.9µm, LED flash, AI, HDR, Full HD video rec.', 'Resolution': 'Full HD+ 1080 x 2340 pixels (402 ppi)', 'Display': 'Full-View AMOLED On-Cell display with Corning Gorilla Glass 6 protection', 'os': 'Android Oreo v8.1 (ColorOS 5.2 based)', 'Memory': '128 GB ROM, 8 GB RAM', 'Main Camera': '(Triple) 12+20 Megapixel & TOF 3D stereo camera- F1.5 /F2.4 & f/2.6, dual-LED flash, Dual Pixel PDAF, Ultra Night Mode, OIS, 1.4μm, 1/2.55, 26mm wide lens, 7P lens, AI, panorama, HDR', 'Battery': '2*1850 mAh bi-cell (*3700 mAh non-removable Li-polymer)- SuperVOOC Flash Charge', 'Size': '6.4 inches'}, 'Name': 'R17 Pro', 'imageUrl': 'https://firebasestorage.googleapis.com/v0/b/e-commerecreact.appspot.com/o/image%2FR17%20Pro.jpg?alt=media&token=c3d7caa3-12f6-4f0d-817a-f9fad4037522', 'price': '69,999', 'Brand': 'Oppo'}
# Redmi 6A => {'id': '10', 'Specification': {'CPU': 'Quad-core, 2.0 GHz', 'Network': 'GSM/LTE/HSPA', 'Chipset': 'MediaTek Helio A22', 'GPU': 'PowerVR GE8320', 'Resolution': 'HD 720 x 1280 pixels (295 ppi)', 'Display': '18:9 ration Full-View IPS LCD Touchscreen', 'os': 'Android Oreo v8.1 (based on MIUI 9.0)', 'Selfie Camera': '  5 Megapixel- F/2.2 aperture, portrait mode, HDR)', 'Memory': '16 GB ROM, 2 GB RAM', 'Main Camera': '13 Megapixel- Phase detection autofocus (PDAF), HDR, panorama, low light photo enhancement', 'Battery': 'Lithium-ion 3000 mAh (non-removable)', 'Size': '5.45 inches'}, 'Name': 'Redmi 6A', 'imageUrl': 'https://firebasestorage.googleapis.com/v0/b/e-commerecreact.appspot.com/o/image%2Fredmi6.jpg?alt=media&token=af4ee57b-7b0f-4dea-bb42-2921593df9cf', 'price': '9,999', 'Brand': 'Xiaomi'}
# Redmi Note 6 Pro => {'id': '8', 'Specification': {'CPU': 'Octa-core, 1.8 GHz', 'Network': 'GSM/LTE/HSPA', 'GPU': 'Adreno 509', 'Chipset': 'Qualcomm Snapdragon 636 (14 nm)', 'Resolution': 'Full HD+ 1080 x 2280 pixels (403 ppi)', 'Display': '19:9 ratio Full-View IPS LCD Touchscreen with Corning Gorilla Glass protection', 'os': 'Android Oreo v8.1 (based on MIUI 9.0)', 'Selfie Camera': 'Dual 20 +2 Megapixel- F/2.0 & f/2.2, 0.9 & 1.75µm, 4-in-1 Super Pixel, HDR, full-HD video rec., face detection, portrait mode, AI', 'Memory': '32 GB ROM, 3 GB RAM', 'Main Camera': 'Dual 12+5 Megapixel- F/1.9 & f/2.2, 1.4 & 1.12µm, dual pixel autofocus, dual-LED flash, HDR, panorama, face recognition, dynamic bokeh, AI', 'Battery': 'Lithium-polymer 4000 mAh (non-removable)- 5V/2A Charging', 'Size': '6.26 inches'}, 'Name': 'Redmi Note 6 Pro', 'imageUrl': 'https://firebasestorage.googleapis.com/v0/b/e-commerecreact.appspot.com/o/image%2Fredmi6pro.jpg?alt=media&token=aceeb92c-6589-415b-88b5-e0fd1bb3badb', 'price': '17,499', 'Brand': 'Xiaomi'}
# Y5 lite => {'id': '5', 'Specification': {'CPU': 'Quad-core, 1.5 GHz', 'Network': 'GSM/LTE/HSPA', 'Chipset': 'MediaTek MT6739', 'GPU': 'Mali-G76 MP10', 'Resolution': 'HD+ 720 x 1440 pixel', 'Display': '18:9 ratio Full-View Touchscreen', 'os': 'Android 8.1 (Oreo), upgradable to Android 9.0 (Pie)', 'Memory': '16 GB, 1 GB RAM', 'Selfie Camera': '5 Megapixel', 'Main Camera': '8 Megapixel', 'Size': '5.45 inches', 'Battery': 'Lithium-ion 3020 mAh (non-removable)'}, 'Name': 'Y5 lite', 'imageUrl': 'https://firebasestorage.googleapis.com/v0/b/e-commerecreact.appspot.com/o/image%2FHUAWEI_Y5_Lite_2018_L_1.jpg?alt=media&token=8ee8967c-5adb-4cc8-bae0-c95091cf986f', 'Brand': 'Huawei', 'price': '8,990'}
# mate 20 pro => {'id': '3', 'Specification': {'CPU': 'Octa-core (4x2.4 GHz Cortex-A73 & 4x1.8 GHz Cortex-A53)', 'Network': 'GSM/LTE/HSPA', 'GPU': 'Mali-G72 MP12', 'Chipset': 'Hisilicon Kirin 970 (10 nm)', 'Resolution': '19.5:9 ratio Full-View AMOLED Touchscreen with Corning Gorilla Glass protection', 'os': 'Android Pie v9.0 (EMUI 9.0)', 'Display': 'AMOLED capacitive touchscreen, 16M colors', 'Memory': '256 GB, 8 GB RAM or 128 GB, 6 GB RAM', 'Selfie Camera': '24 Megapixel- F/2.0 aperture, 3D depth sensing, 26mm wide-angle lens, HDR, Full HD video re', 'Main Camera': '40 MP, f/1.8, 27mm (wide), 1/1.7, OIS, PDAF/Laser AF 20 MP B/W, f/1.6, 27mm (wide), 1/2.7, OIS, PDAF/Laser AF 8 MP, f/2.4, 80mm (telephoto), 1/4, 3x optical zoom, OIS, PDAF/Laser AF,2160p@30fps, 1080p@60fps, 1080p@30fps (gyro-EIS), 720p@960fps', 'Battery': 'Non-removable Li-Po 4000 mAh battery', 'Size': '6.39 inches'}, 'Name': 'mate 20 pro', 'imageUrl': 'https://firebasestorage.googleapis.com/v0/b/e-commerecreact.appspot.com/o/image%2FMate20pro.jpg?alt=media&token=4464cf49-3108-4c33-97a1-34ec36b83daa', 'price': '89,990', 'Brand': 'Huawei'}
# p20 pro => {'id': '4', 'Specification': {'CPU': 'Octa-core (2x2.6 GHz Cortex-A76 & 2x1.92 GHz Cortex-A76 & 4x1.8 GHz Cortex-A55)', 'Network': 'GSM/LTE/HSPA', 'Chipset': 'HiSilicon Kirin 980', 'GPU': 'Mali-G76 MP10', 'Resolution': '1080 x 2240 pixels, 18.7:9 ratio (~408 ppi density)', 'Display': '6.39 inches, 2K+ 1440 x 3120 pixels (538 ppi', 'os': 'Android 8.1 (Oreo), upgradable to Android 9.0 (Pie)', 'Memory': '256 GB, 8 GB RAM or 128 GB, 6 GB RAM', 'Selfie Camera': '24 MP, f/2.0, 26mm (wide),1080p@30fps', 'Main Camera': 'Leica Triple Camera 40+20+8 MP- 27mm wide-angle lens, 80mm telephoto lens, 1/4, 16mm ultrawide lens, 1/2.7, 5x optical zoom, OIS, 1/1.7, PDAF/Laser autofocus, Leica optics, dual-LED flash, HDR, panorama mode, AIS (AI Image Stabilization)', 'Size': '6.1 inches', 'Battery': 'Lithium-polymer 4200 mAh (non-removable)'}, 'Name': 'p20 pro', 'imageUrl': 'https://firebasestorage.googleapis.com/v0/b/e-commerecreact.appspot.com/o/image%2Fp20%20pro.jpg?alt=media&token=7c5ec3ce-7b28-4fee-9441-a771ab1b1f7d', 'price': '82,900', 'Brand': 'Huawei'}
